# %% [markdown]
# <a href="https://colab.research.google.com/github/namyh/hw3/blob/main/hw4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
import os

# %%
os.chdir('/content/drive/MyDrive/deep_learning_ex/ch08')

# %%
run train.py
# Out:
# | 에폭 1 |  반복 1 / 351 | 시간 0[s] | 손실 4.08
# | 에폭 1 |  반복 21 / 351 | 시간 14[s] | 손실 3.09
# | 에폭 1 |  반복 41 / 351 | 시간 29[s] | 손실 1.90
# | 에폭 1 |  반복 61 / 351 | 시간 43[s] | 손실 1.72
# | 에폭 1 |  반복 81 / 351 | 시간 57[s] | 손실 1.46
# | 에폭 1 |  반복 101 / 351 | 시간 71[s] | 손실 1.19
# | 에폭 1 |  반복 121 / 351 | 시간 85[s] | 손실 1.14
# | 에폭 1 |  반복 141 / 351 | 시간 99[s] | 손실 1.09
# | 에폭 1 |  반복 161 / 351 | 시간 113[s] | 손실 1.06
# | 에폭 1 |  반복 181 / 351 | 시간 127[s] | 손실 1.04
# | 에폭 1 |  반복 201 / 351 | 시간 141[s] | 손실 1.03
# | 에폭 1 |  반복 221 / 351 | 시간 154[s] | 손실 1.02
# | 에폭 1 |  반복 241 / 351 | 시간 168[s] | 손실 1.02
# | 에폭 1 |  반복 261 / 351 | 시간 181[s] | 손실 1.01
# | 에폭 1 |  반복 281 / 351 | 시간 195[s] | 손실 1.00
# | 에폭 1 |  반복 301 / 351 | 시간 208[s] | 손실 1.00
# | 에폭 1 |  반복 321 / 351 | 시간 222[s] | 손실 1.00
# | 에폭 1 |  반복 341 / 351 | 시간 236[s] | 손실 1.00
# Q 10/15/94
# T 1994-10-15
# ☒ 1978-08-11
# ---
# Q thursday, november 13, 2008
# T 2008-11-13
# ☒ 1978-08-11
# ---
# Q Mar 25, 2003
# T 2003-03-25
# ☒ 1978-08-11
# ...

# %%
x = np.arange(len(acc_list))
plt.plot(x, acc_list, marker='o')
plt.xlabel('epoch')
plt.ylabel('accuracy')
plt.ylim(-0.05, 1.05)
plt.show()

# %%
os.chdir('/content/drive/MyDrive/deep_learning_ex/ch08')

# %%
run visualize_attention.py

# %%
os.chdir('/content/drive/MyDrive/deep_learning_ex/ch08')

# %%
#simple seq2seq
# Out:
#   File "<ipython-input-19-aa25f0c57625>", line 2
#     run train.py
#             ^
# SyntaxError: invalid syntax

# %%
run train.py
# Out:
# | 에폭 1 |  반복 1 / 351 | 시간 0[s] | 손실 4.08
# | 에폭 1 |  반복 21 / 351 | 시간 7[s] | 손실 3.34
# | 에폭 1 |  반복 41 / 351 | 시간 15[s] | 손실 1.95
# | 에폭 1 |  반복 61 / 351 | 시간 23[s] | 손실 1.78
# | 에폭 1 |  반복 81 / 351 | 시간 30[s] | 손실 1.70
# | 에폭 1 |  반복 101 / 351 | 시간 38[s] | 손실 1.55
# | 에폭 1 |  반복 121 / 351 | 시간 46[s] | 손실 1.27
# | 에폭 1 |  반복 141 / 351 | 시간 53[s] | 손실 1.16
# | 에폭 1 |  반복 161 / 351 | 시간 61[s] | 손실 1.12
# | 에폭 1 |  반복 181 / 351 | 시간 68[s] | 손실 1.08
# | 에폭 1 |  반복 201 / 351 | 시간 76[s] | 손실 1.06
# | 에폭 1 |  반복 221 / 351 | 시간 83[s] | 손실 1.05
# | 에폭 1 |  반복 241 / 351 | 시간 91[s] | 손실 1.04
# | 에폭 1 |  반복 261 / 351 | 시간 98[s] | 손실 1.04
# | 에폭 1 |  반복 281 / 351 | 시간 106[s] | 손실 1.03
# | 에폭 1 |  반복 301 / 351 | 시간 114[s] | 손실 1.03
# | 에폭 1 |  반복 321 / 351 | 시간 121[s] | 손실 1.03
# | 에폭 1 |  반복 341 / 351 | 시간 129[s] | 손실 1.02
# Q 10/15/94
# T 1994-10-15
# ☒ 1999-01-11
# ---
# Q thursday, november 13, 2008
# T 2008-11-13
# ☒ 1999-01-11
# ---
# Q Mar 25, 2003
# T 2003-03-25
# ☒ 1999-01-11
# ---
# ...

# %%
run train.py
# Out:
# | 에폭 1 |  반복 1 / 351 | 시간 0[s] | 손실 4.08
# | 에폭 1 |  반복 21 / 351 | 시간 9[s] | 손실 2.86
# | 에폭 1 |  반복 41 / 351 | 시간 18[s] | 손실 1.89
# | 에폭 1 |  반복 61 / 351 | 시간 26[s] | 손실 1.78
# | 에폭 1 |  반복 81 / 351 | 시간 35[s] | 손실 1.70
# | 에폭 1 |  반복 101 / 351 | 시간 44[s] | 손실 1.57
# | 에폭 1 |  반복 121 / 351 | 시간 53[s] | 손실 1.30
# | 에폭 1 |  반복 141 / 351 | 시간 62[s] | 손실 1.16
# | 에폭 1 |  반복 161 / 351 | 시간 70[s] | 손실 1.10
# | 에폭 1 |  반복 181 / 351 | 시간 79[s] | 손실 1.07
# | 에폭 1 |  반복 201 / 351 | 시간 88[s] | 손실 1.05
# | 에폭 1 |  반복 221 / 351 | 시간 97[s] | 손실 1.04
# | 에폭 1 |  반복 241 / 351 | 시간 106[s] | 손실 1.04
# | 에폭 1 |  반복 261 / 351 | 시간 114[s] | 손실 1.03
# | 에폭 1 |  반복 281 / 351 | 시간 123[s] | 손실 1.02
# | 에폭 1 |  반복 301 / 351 | 시간 132[s] | 손실 1.01
# | 에폭 1 |  반복 321 / 351 | 시간 141[s] | 손실 1.00
# | 에폭 1 |  반복 341 / 351 | 시간 149[s] | 손실 1.00
# Q 10/15/94
# T 1994-10-15
# ☒ 1971-11-11
# ---
# Q thursday, november 13, 2008
# T 2008-11-13
# ☒ 1973-01-11
# ---
# Q Mar 25, 2003
# T 2003-03-25
# ☒ 1983-03-03
# ---
# ...
